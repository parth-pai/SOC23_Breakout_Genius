# %% [markdown]
# <a href="https://colab.research.google.com/github/parth-pai/SOC23_Breakout_Genius/blob/main/SOC_Training_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Required Installations
# !pip install gym==0.25.2
# !pip install gym[atari]
# !pip install gym[accept-rom-license]
# Out:
# Requirement already satisfied: gym==0.25.2 in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.25.2) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.25.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.25.2) (0.0.8)
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[atari]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[atari]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[atari]) (0.0.8)
# Requirement already satisfied: ale-py~=0.7.5 in /usr/local/lib/python3.10/dist-packages (from gym[atari]) (0.7.5)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.7.5->gym[atari]) (6.0.0)
# Requirement already satisfied: gym[accept-rom-license] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[accept-rom-license]) (0.0.8)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gym[accept-rom-license])
#   Using cached AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license]) (8.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license]) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license]) (4.65.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license])
#   Using cached AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license]) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license]) (3.4)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=47aa133c6b3ce220b9a95e11e78543fabd878a5d0f1377c3dd75603c9142ba7a
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2

# %%
#Importing all necessary libraries
import random
import numpy as np
import torch
import torch.nn as nn
import gym
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import convolve, gaussian

from collections import deque
from torch.nn.functional import mse_loss
import torch.optim as optim

import os
import io
import base64
import time
import glob
from IPython.display import HTML

# %%
from gym.wrappers import AtariPreprocessing
from gym.wrappers import FrameStack
from gym.wrappers import TransformReward

#Gives out environment using OpenAI's gym module
def make_env(env_name, clip_rewards = True, seed = None):
    env = gym.make(env_name)
    env = AtariPreprocessing(env)
    env = FrameStack(env,num_stack = 4)
    if clip_rewards:
        env = TransformReward(env, lambda r: np.sign(r))
    return env

# %%
#Giving GPU access if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#Our main DQNAgent class
class DQNAgent(nn.Module):
    def __init__(self, state_shape, n_actions, epsilon):
		# state_shape --> Input shape to the Neural Network
		# n_actions --> Number of actions
		# epsilon --> Exploration Probability
        super(DQNAgent,self).__init__()
        self.n_actions = n_actions
        self.epsilon = epsilon

    #Initialising Neural Network using these layers
		# 1) A Convolutional layer followed by ReLU activation function
        self.conv1 = nn.Conv2d(4,16,kernel_size=8,stride=4)
        self.relu1 = nn.ReLU()
		# 2) A Convolutional layer followed by ReLU activation function
        self.conv2 = nn.Conv2d(16,32,kernel_size=4,stride=2)
        self.relu2 = nn.ReLU()
    # 3) A Linear layer to give output
        self.flatten = nn.Flatten()
        self.linear = nn.Linear(32*((((state_shape[1]-8)//4 + 1)-4)//2 + 1)*((((state_shape[2]-8)//4 + 1)-4)//2 + 1),256)
        self.relu3 = nn.ReLU()
    # 4) linear Layer with output size = 'number of actions'(the qvalues of actions)
        self.qvalues = nn.Linear(256,n_actions)

    def forward(self, state_t):
        state_t = torch.tensor(np.array(state_t), dtype=torch.float32)
        x = self.relu1(self.conv1(state_t))
        x = self.relu2(self.conv2(x))
        x = self.relu3(self.linear(self.flatten(x)))
		# returns qvalues
        return self.qvalues(x)

    def get_qvalues(self, state_t):
        x = self.forward(state_t)
    # returns the numpy array of qvalues
        return x.detach().numpy()

    def sample_actions(self, qvalues):
		# sample_actions based on the qvalues
        batch_size = qvalues.shape[0]
        actions = np.zeros(batch_size,dtype=np.int64)
        for i in range(batch_size):
            if(np.random.rand() < self.epsilon):
                actions[i] = np.random.randint(low=0,high=self.n_actions)
            else:
                actions[i] = np.argmax(qvalues[i])
        return actions

# %%
#Evaluating the training agent
def evaluate(env, agent, n_games = 1, greedy = False, t_max = 10000):
	# returns the mean of sum of all rewards across n_games
    rewards = []
    for _ in range(n_games):
        s = env.reset()
        R = 0.0
        for _ in range(t_max):
            qvalues = agent.get_qvalues([s])
            if greedy:
                action = qvalues.argmax(axis=-1)[0]
            else:
                action = agent.sample_actions(qvalues)[0]
            s,r,done,_ = env.step(action)
            R += r
            if done:
                break
        rewards.append(R)
    return np.mean(rewards)

# %%
#ReplayBuffer class
class ReplayBuffer:
    def __init__(self, size):
		# maximum size that buffer can hold
        self.buffer = deque(maxlen=size)

    def __len__(self):
        return len(self.buffer)

    def add(self, state, action ,reward, next_state, done):
		# store the information passed in one call to add as 1 unit of informmation
        self.buffer.append((state,action,reward,next_state,done))

    def sample(self, batch_size):
		# return a random sampling of 'batch_size' units of information
        states,actions,rewards,next_states,dones = zip(*random.sample(self.buffer,batch_size))
        return np.array(states),np.array(actions),np.array(rewards),np.array(next_states),np.array(dones)

# %%
#Make the agent play on the env and store the information in exp_replay
def play_and_record(start_state, agent, env, exp_replay, n_steps = 1):
	# n_steps --> number of steps to be played in this function on one call
    s = start_state
    for _ in range(n_steps):
        qvalues = agent.get_qvalues([s])
        a = agent.sample_actions(qvalues)[0]
        next_s,r,done,_ = env.step(a)
        exp_replay.add(s,a,r,next_s,done)
        if not done:
            s = next_s
        else:
            s = env.reset()

# %%
#Computing TD Loss
def compute_td_loss(agent, target_network,device, batch_size, exp_replay, gamma = 0.99):
	# sample 'batch_size' units of info stored in the exp_replay
    states,actions,rewards,next_states,dones = exp_replay.sample(batch_size)
  # Need to convert back the objects into tensors using PyTorch
    states = torch.tensor(states, device=device, dtype=torch.float)
    actions = torch.tensor(actions,device=device,dtype=torch.long)
    rewards = torch.tensor(rewards, device=device, dtype=torch.float)
    next_states = torch.tensor(next_states, device=device, dtype=torch.float)
    dones = torch.tensor(dones.astype('float32'),device=device, dtype=torch.float)
	# Find predicted qvalues and target qvalues and then MSELoss of them
    predicted_qvalues = agent(states)
  # forward call in DQNAgent class
    predicted_qvalues_of_actions = predicted_qvalues[range(batch_size),actions]

    with torch.no_grad():
        target_qvalues_of_actions = target_network(next_states).max(-1)[0]
        target_qvalues_of_actions = rewards + (gamma * target_qvalues_of_actions * (1 - dones))

    return mse_loss(predicted_qvalues_of_actions,target_qvalues_of_actions)

# %%
#### MAIN LOOP ####

#More libraries
from tqdm import trange
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %%
# Function to plot the rewards and loss
seed = 108
random.seed(108)
np.random.seed(108)
torch.manual_seed(108)

# %%
#Setting up environment
env_name = "BreakoutNoFrameskip-v4"
# Reset the environment before starting to train the agent and everytime the game ends (U will get a done flag which is a boolean representing whether the game has ended or not)
env = make_env(env_name)
state = env.reset()
state_shape = env.observation_space.shape
n_actions = env.action_space.n
epsilon = 0.5
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:227: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(

# %%
#Create agent from DQNAgent class
agent = DQNAgent(state_shape,n_actions,epsilon).to(device)
#Create target_network from DQNAgent class is updated after some fixed steps from agent
target_network = DQNAgent(state_shape,n_actions,epsilon).to(device)
# Note initialise target network values from agent
target_network.load_state_dict(agent.state_dict())
# Out:
# <All keys matched successfully>

# %%
# Creating a ReplayBuffer object and saving some information in the object by playing the agent
exp_replay = ReplayBuffer(10**6)
for i in range(4000):
    play_and_record(state, agent, env, exp_replay, n_steps=10**2)
    print( "Replay Buffer : i : ", i)
    if len(exp_replay) == 10**6:
        break
print(len(exp_replay))
# Out:
# Replay Buffer : i :  0
# Replay Buffer : i :  1
# Replay Buffer : i :  2
# Replay Buffer : i :  3
# Replay Buffer : i :  4
# Replay Buffer : i :  5
# Replay Buffer : i :  6
# Replay Buffer : i :  7
# Replay Buffer : i :  8
# Replay Buffer : i :  9
# Replay Buffer : i :  10
# Replay Buffer : i :  11
# Replay Buffer : i :  12
# Replay Buffer : i :  13
# Replay Buffer : i :  14
# Replay Buffer : i :  15
# Replay Buffer : i :  16
# Replay Buffer : i :  17
# Replay Buffer : i :  18
# Replay Buffer : i :  19
# Replay Buffer : i :  20
# Replay Buffer : i :  21
# Replay Buffer : i :  22
# Replay Buffer : i :  23
# Replay Buffer : i :  24
# Replay Buffer : i :  25
# Replay Buffer : i :  26
# Replay Buffer : i :  27
# Replay Buffer : i :  28
# Replay Buffer : i :  29
# Replay Buffer : i :  30
# Replay Buffer : i :  31
# Replay Buffer : i :  32
# Replay Buffer : i :  33
# Replay Buffer : i :  34
# Replay Buffer : i :  35
# Replay Buffer : i :  36
# Replay Buffer : i :  37
# Replay Buffer : i :  38
# Replay Buffer : i :  39
# Replay Buffer : i :  40
# Replay Buffer : i :  41
# Replay Buffer : i :  42
# Replay Buffer : i :  43
# Replay Buffer : i :  44
# Replay Buffer : i :  45
# Replay Buffer : i :  46
# Replay Buffer : i :  47
# Replay Buffer : i :  48
# Replay Buffer : i :  49
# Replay Buffer : i :  50
# Replay Buffer : i :  51
# Replay Buffer : i :  52
# Replay Buffer : i :  53
# Replay Buffer : i :  54
# Replay Buffer : i :  55
# Replay Buffer : i :  56
# Replay Buffer : i :  57
# Replay Buffer : i :  58
# Replay Buffer : i :  59
# Replay Buffer : i :  60
# Replay Buffer : i :  61
# Replay Buffer : i :  62
# Replay Buffer : i :  63
# Replay Buffer : i :  64
# Replay Buffer : i :  65
# Replay Buffer : i :  66
# Replay Buffer : i :  67
# Replay Buffer : i :  68
# Replay Buffer : i :  69
# Replay Buffer : i :  70
# Replay Buffer : i :  71
# Replay Buffer : i :  72
# Replay Buffer : i :  73
# Replay Buffer : i :  74
# Replay Buffer : i :  75
# Replay Buffer : i :  76
# Replay Buffer : i :  77
# Replay Buffer : i :  78
# Replay Buffer : i :  79
# Replay Buffer : i :  80
# Replay Buffer : i :  81
# Replay Buffer : i :  82
# Replay Buffer : i :  83
# Replay Buffer : i :  84
# Replay Buffer : i :  85
# Replay Buffer : i :  86
# Replay Buffer : i :  87
# Replay Buffer : i :  88
# Replay Buffer : i :  89
# Replay Buffer : i :  90
# Replay Buffer : i :  91
# Replay Buffer : i :  92
# Replay Buffer : i :  93
# Replay Buffer : i :  94
# Replay Buffer : i :  95
# Replay Buffer : i :  96
# Replay Buffer : i :  97
# Replay Buffer : i :  98
# Replay Buffer : i :  99
# Replay Buffer : i :  100
# Replay Buffer : i :  101
# Replay Buffer : i :  102
# Replay Buffer : i :  103
# Replay Buffer : i :  104
# Replay Buffer : i :  105
# Replay Buffer : i :  106
# Replay Buffer : i :  107
# Replay Buffer : i :  108
# Replay Buffer : i :  109
# Replay Buffer : i :  110
# Replay Buffer : i :  111
# Replay Buffer : i :  112
# Replay Buffer : i :  113
# Replay Buffer : i :  114
# Replay Buffer : i :  115
# Replay Buffer : i :  116
# Replay Buffer : i :  117
# Replay Buffer : i :  118
# Replay Buffer : i :  119
# Replay Buffer : i :  120
# Replay Buffer : i :  121
# Replay Buffer : i :  122
# Replay Buffer : i :  123
# Replay Buffer : i :  124
# Replay Buffer : i :  125
# Replay Buffer : i :  126
# Replay Buffer : i :  127
# Replay Buffer : i :  128
# Replay Buffer : i :  129
# Replay Buffer : i :  130
# Replay Buffer : i :  131
# Replay Buffer : i :  132
# Replay Buffer : i :  133
# Replay Buffer : i :  134
# Replay Buffer : i :  135
# Replay Buffer : i :  136
# Replay Buffer : i :  137
# Replay Buffer : i :  138
# Replay Buffer : i :  139
# Replay Buffer : i :  140
# Replay Buffer : i :  141
# Replay Buffer : i :  142
# Replay Buffer : i :  143
# Replay Buffer : i :  144
# Replay Buffer : i :  145
# Replay Buffer : i :  146
# Replay Buffer : i :  147
# Replay Buffer : i :  148
# Replay Buffer : i :  149
# Replay Buffer : i :  150
# Replay Buffer : i :  151
# Replay Buffer : i :  152
# Replay Buffer : i :  153
# Replay Buffer : i :  154
# Replay Buffer : i :  155
# Replay Buffer : i :  156
# Replay Buffer : i :  157
# Replay Buffer : i :  158
# Replay Buffer : i :  159
# Replay Buffer : i :  160
# Replay Buffer : i :  161
# Replay Buffer : i :  162
# Replay Buffer : i :  163
# Replay Buffer : i :  164
# Replay Buffer : i :  165
# Replay Buffer : i :  166
# Replay Buffer : i :  167
# Replay Buffer : i :  168
# Replay Buffer : i :  169
# Replay Buffer : i :  170
# Replay Buffer : i :  171
# Replay Buffer : i :  172
# Replay Buffer : i :  173
# Replay Buffer : i :  174
# Replay Buffer : i :  175
# Replay Buffer : i :  176
# Replay Buffer : i :  177
# Replay Buffer : i :  178
# Replay Buffer : i :  179
# Replay Buffer : i :  180
# Replay Buffer : i :  181
# Replay Buffer : i :  182
# Replay Buffer : i :  183
# Replay Buffer : i :  184
# Replay Buffer : i :  185
# Replay Buffer : i :  186
# Replay Buffer : i :  187
# Replay Buffer : i :  188
# Replay Buffer : i :  189
# Replay Buffer : i :  190
# Replay Buffer : i :  191
# Replay Buffer : i :  192
# Replay Buffer : i :  193
# Replay Buffer : i :  194
# Replay Buffer : i :  195
# Replay Buffer : i :  196
# Replay Buffer : i :  197
# Replay Buffer : i :  198
# Replay Buffer : i :  199
# Replay Buffer : i :  200
# Replay Buffer : i :  201
# Replay Buffer : i :  202
# Replay Buffer : i :  203
# Replay Buffer : i :  204
# Replay Buffer : i :  205
# Replay Buffer : i :  206
# Replay Buffer : i :  207
# Replay Buffer : i :  208
# Replay Buffer : i :  209
# Replay Buffer : i :  210
# Replay Buffer : i :  211
# Replay Buffer : i :  212
# Replay Buffer : i :  213
# Replay Buffer : i :  214
# Replay Buffer : i :  215
# Replay Buffer : i :  216
# Replay Buffer : i :  217
# Replay Buffer : i :  218
# Replay Buffer : i :  219
# Replay Buffer : i :  220
# Replay Buffer : i :  221
# Replay Buffer : i :  222
# Replay Buffer : i :  223
# Replay Buffer : i :  224
# Replay Buffer : i :  225
# Replay Buffer : i :  226
# Replay Buffer : i :  227
# Replay Buffer : i :  228
# Replay Buffer : i :  229
# Replay Buffer : i :  230
# Replay Buffer : i :  231
# Replay Buffer : i :  232
# Replay Buffer : i :  233
# Replay Buffer : i :  234
# Replay Buffer : i :  235
# Replay Buffer : i :  236
# Replay Buffer : i :  237
# Replay Buffer : i :  238
# Replay Buffer : i :  239
# Replay Buffer : i :  240
# Replay Buffer : i :  241
# Replay Buffer : i :  242
# Replay Buffer : i :  243
# Replay Buffer : i :  244
# Replay Buffer : i :  245
# Replay Buffer : i :  246
# Replay Buffer : i :  247
# Replay Buffer : i :  248
# Replay Buffer : i :  249
# Replay Buffer : i :  250
# Replay Buffer : i :  251
# Replay Buffer : i :  252
# Replay Buffer : i :  253
# Replay Buffer : i :  254
# Replay Buffer : i :  255
# Replay Buffer : i :  256
# Replay Buffer : i :  257
# Replay Buffer : i :  258
# Replay Buffer : i :  259
# Replay Buffer : i :  260
# Replay Buffer : i :  261
# Replay Buffer : i :  262
# Replay Buffer : i :  263
# Replay Buffer : i :  264
# Replay Buffer : i :  265
# Replay Buffer : i :  266
# Replay Buffer : i :  267
# Replay Buffer : i :  268
# Replay Buffer : i :  269
# Replay Buffer : i :  270
# Replay Buffer : i :  271
# Replay Buffer : i :  272
# Replay Buffer : i :  273
# Replay Buffer : i :  274
# Replay Buffer : i :  275
# Replay Buffer : i :  276
# Replay Buffer : i :  277
# Replay Buffer : i :  278
# Replay Buffer : i :  279
# Replay Buffer : i :  280
# Replay Buffer : i :  281
# Replay Buffer : i :  282
# Replay Buffer : i :  283
# Replay Buffer : i :  284
# Replay Buffer : i :  285
# Replay Buffer : i :  286
# Replay Buffer : i :  287
# Replay Buffer : i :  288
# Replay Buffer : i :  289
# Replay Buffer : i :  290
# Replay Buffer : i :  291
# Replay Buffer : i :  292
# Replay Buffer : i :  293
# Replay Buffer : i :  294
# Replay Buffer : i :  295
# Replay Buffer : i :  296
# Replay Buffer : i :  297
# Replay Buffer : i :  298
# Replay Buffer : i :  299
# Replay Buffer : i :  300
# Replay Buffer : i :  301
# Replay Buffer : i :  302
# Replay Buffer : i :  303
# Replay Buffer : i :  304
# Replay Buffer : i :  305
# Replay Buffer : i :  306
# Replay Buffer : i :  307
# Replay Buffer : i :  308
# Replay Buffer : i :  309
# Replay Buffer : i :  310
# Replay Buffer : i :  311
# Replay Buffer : i :  312
# Replay Buffer : i :  313
# Replay Buffer : i :  314
# Replay Buffer : i :  315
# Replay Buffer : i :  316
# Replay Buffer : i :  317
# Replay Buffer : i :  318
# Replay Buffer : i :  319
# Replay Buffer : i :  320
# Replay Buffer : i :  321
# Replay Buffer : i :  322
# Replay Buffer : i :  323
# Replay Buffer : i :  324
# Replay Buffer : i :  325
# Replay Buffer : i :  326
# Replay Buffer : i :  327
# Replay Buffer : i :  328
# Replay Buffer : i :  329
# Replay Buffer : i :  330
# Replay Buffer : i :  331
# Replay Buffer : i :  332
# Replay Buffer : i :  333
# Replay Buffer : i :  334
# Replay Buffer : i :  335
# Replay Buffer : i :  336
# Replay Buffer : i :  337
# Replay Buffer : i :  338
# Replay Buffer : i :  339
# Replay Buffer : i :  340
# Replay Buffer : i :  341
# Replay Buffer : i :  342
# Replay Buffer : i :  343
# Replay Buffer : i :  344
# Replay Buffer : i :  345
# Replay Buffer : i :  346
# Replay Buffer : i :  347
# Replay Buffer : i :  348
# Replay Buffer : i :  349
# Replay Buffer : i :  350
# Replay Buffer : i :  351
# Replay Buffer : i :  352
# Replay Buffer : i :  353
# Replay Buffer : i :  354
# Replay Buffer : i :  355
# Replay Buffer : i :  356
# Replay Buffer : i :  357
# Replay Buffer : i :  358
# Replay Buffer : i :  359
# Replay Buffer : i :  360
# Replay Buffer : i :  361
# Replay Buffer : i :  362
# Replay Buffer : i :  363
# Replay Buffer : i :  364
# Replay Buffer : i :  365
# Replay Buffer : i :  366
# Replay Buffer : i :  367
# Replay Buffer : i :  368
# Replay Buffer : i :  369
# Replay Buffer : i :  370
# Replay Buffer : i :  371
# Replay Buffer : i :  372
# Replay Buffer : i :  373
# Replay Buffer : i :  374
# Replay Buffer : i :  375
# Replay Buffer : i :  376
# Replay Buffer : i :  377
# Replay Buffer : i :  378
# Replay Buffer : i :  379
# Replay Buffer : i :  380
# Replay Buffer : i :  381
# Replay Buffer : i :  382
# Replay Buffer : i :  383
# Replay Buffer : i :  384
# Replay Buffer : i :  385
# Replay Buffer : i :  386
# Replay Buffer : i :  387
# Replay Buffer : i :  388
# Replay Buffer : i :  389
# Replay Buffer : i :  390
# Replay Buffer : i :  391
# Replay Buffer : i :  392
# Replay Buffer : i :  393
# Replay Buffer : i :  394
# Replay Buffer : i :  395
# Replay Buffer : i :  396
# Replay Buffer : i :  397
# Replay Buffer : i :  398
# Replay Buffer : i :  399
# Replay Buffer : i :  400
# Replay Buffer : i :  401
# Replay Buffer : i :  402
# Replay Buffer : i :  403
# Replay Buffer : i :  404
# Replay Buffer : i :  405
# Replay Buffer : i :  406
# Replay Buffer : i :  407
# Replay Buffer : i :  408
# Replay Buffer : i :  409
# Replay Buffer : i :  410
# Replay Buffer : i :  411
# Replay Buffer : i :  412
# Replay Buffer : i :  413
# Replay Buffer : i :  414
# Replay Buffer : i :  415
# Replay Buffer : i :  416
# Replay Buffer : i :  417
# Replay Buffer : i :  418
# Replay Buffer : i :  419
# Replay Buffer : i :  420
# Replay Buffer : i :  421
# Replay Buffer : i :  422
# Replay Buffer : i :  423
# Replay Buffer : i :  424
# Replay Buffer : i :  425
# Replay Buffer : i :  426
# Replay Buffer : i :  427
# Replay Buffer : i :  428
# Replay Buffer : i :  429
# Replay Buffer : i :  430
# Replay Buffer : i :  431
# Replay Buffer : i :  432
# Replay Buffer : i :  433
# Replay Buffer : i :  434
# Replay Buffer : i :  435
# Replay Buffer : i :  436
# Replay Buffer : i :  437
# Replay Buffer : i :  438
# Replay Buffer : i :  439
# Replay Buffer : i :  440
# Replay Buffer : i :  441
# Replay Buffer : i :  442
# Replay Buffer : i :  443
# Replay Buffer : i :  444
# Replay Buffer : i :  445
# Replay Buffer : i :  446
# Replay Buffer : i :  447
# Replay Buffer : i :  448
# Replay Buffer : i :  449
# Replay Buffer : i :  450
# Replay Buffer : i :  451
# Replay Buffer : i :  452
# Replay Buffer : i :  453
# Replay Buffer : i :  454
# Replay Buffer : i :  455
# Replay Buffer : i :  456
# Replay Buffer : i :  457
# Replay Buffer : i :  458
# Replay Buffer : i :  459
# Replay Buffer : i :  460
# Replay Buffer : i :  461
# Replay Buffer : i :  462
# Replay Buffer : i :  463
# Replay Buffer : i :  464
# Replay Buffer : i :  465
# Replay Buffer : i :  466
# Replay Buffer : i :  467
# Replay Buffer : i :  468
# Replay Buffer : i :  469
# Replay Buffer : i :  470
# Replay Buffer : i :  471
# Replay Buffer : i :  472
# Replay Buffer : i :  473
# Replay Buffer : i :  474
# Replay Buffer : i :  475
# Replay Buffer : i :  476
# Replay Buffer : i :  477
# Replay Buffer : i :  478
# Replay Buffer : i :  479
# Replay Buffer : i :  480
# Replay Buffer : i :  481
# Replay Buffer : i :  482
# Replay Buffer : i :  483
# Replay Buffer : i :  484
# Replay Buffer : i :  485
# Replay Buffer : i :  486
# Replay Buffer : i :  487
# Replay Buffer : i :  488
# Replay Buffer : i :  489
# Replay Buffer : i :  490
# Replay Buffer : i :  491
# Replay Buffer : i :  492
# Replay Buffer : i :  493
# Replay Buffer : i :  494
# Replay Buffer : i :  495
# Replay Buffer : i :  496
# Replay Buffer : i :  497
# Replay Buffer : i :  498
# Replay Buffer : i :  499
# Replay Buffer : i :  500
# Replay Buffer : i :  501
# Replay Buffer : i :  502
# Replay Buffer : i :  503
# Replay Buffer : i :  504
# Replay Buffer : i :  505
# Replay Buffer : i :  506
# Replay Buffer : i :  507
# Replay Buffer : i :  508
# Replay Buffer : i :  509
# Replay Buffer : i :  510
# Replay Buffer : i :  511
# Replay Buffer : i :  512
# Replay Buffer : i :  513
# Replay Buffer : i :  514
# Replay Buffer : i :  515
# Replay Buffer : i :  516
# Replay Buffer : i :  517
# Replay Buffer : i :  518
# Replay Buffer : i :  519
# Replay Buffer : i :  520
# Replay Buffer : i :  521
# Replay Buffer : i :  522
# Replay Buffer : i :  523
# Replay Buffer : i :  524
# Replay Buffer : i :  525
# Replay Buffer : i :  526
# Replay Buffer : i :  527
# Replay Buffer : i :  528
# Replay Buffer : i :  529
# Replay Buffer : i :  530
# Replay Buffer : i :  531
# Replay Buffer : i :  532
# Replay Buffer : i :  533
# Replay Buffer : i :  534
# Replay Buffer : i :  535
# Replay Buffer : i :  536
# Replay Buffer : i :  537
# Replay Buffer : i :  538
# Replay Buffer : i :  539
# Replay Buffer : i :  540
# Replay Buffer : i :  541
# Replay Buffer : i :  542
# Replay Buffer : i :  543
# Replay Buffer : i :  544
# Replay Buffer : i :  545
# Replay Buffer : i :  546
# Replay Buffer : i :  547
# Replay Buffer : i :  548
# Replay Buffer : i :  549
# Replay Buffer : i :  550
# Replay Buffer : i :  551
# Replay Buffer : i :  552
# Replay Buffer : i :  553
# Replay Buffer : i :  554
# Replay Buffer : i :  555
# Replay Buffer : i :  556
# Replay Buffer : i :  557
# Replay Buffer : i :  558
# Replay Buffer : i :  559
# Replay Buffer : i :  560
# Replay Buffer : i :  561
# Replay Buffer : i :  562
# Replay Buffer : i :  563
# Replay Buffer : i :  564
# Replay Buffer : i :  565
# Replay Buffer : i :  566
# Replay Buffer : i :  567
# Replay Buffer : i :  568
# Replay Buffer : i :  569
# Replay Buffer : i :  570
# Replay Buffer : i :  571
# Replay Buffer : i :  572
# Replay Buffer : i :  573
# Replay Buffer : i :  574
# Replay Buffer : i :  575
# Replay Buffer : i :  576
# Replay Buffer : i :  577
# Replay Buffer : i :  578
# Replay Buffer : i :  579
# Replay Buffer : i :  580
# Replay Buffer : i :  581
# Replay Buffer : i :  582
# Replay Buffer : i :  583
# Replay Buffer : i :  584
# Replay Buffer : i :  585
# Replay Buffer : i :  586
# Replay Buffer : i :  587
# Replay Buffer : i :  588
# Replay Buffer : i :  589
# Replay Buffer : i :  590
# Replay Buffer : i :  591
# Replay Buffer : i :  592
# Replay Buffer : i :  593
# Replay Buffer : i :  594
# Replay Buffer : i :  595
# Replay Buffer : i :  596
# Replay Buffer : i :  597
# Replay Buffer : i :  598
# Replay Buffer : i :  599
# Replay Buffer : i :  600
# Replay Buffer : i :  601
# Replay Buffer : i :  602
# Replay Buffer : i :  603
# Replay Buffer : i :  604
# Replay Buffer : i :  605
# Replay Buffer : i :  606
# Replay Buffer : i :  607
# Replay Buffer : i :  608
# Replay Buffer : i :  609
# Replay Buffer : i :  610
# Replay Buffer : i :  611
# Replay Buffer : i :  612
# Replay Buffer : i :  613
# Replay Buffer : i :  614
# Replay Buffer : i :  615
# Replay Buffer : i :  616
# Replay Buffer : i :  617
# Replay Buffer : i :  618
# Replay Buffer : i :  619
# Replay Buffer : i :  620
# Replay Buffer : i :  621
# Replay Buffer : i :  622
# Replay Buffer : i :  623
# Replay Buffer : i :  624
# Replay Buffer : i :  625
# Replay Buffer : i :  626
# Replay Buffer : i :  627
# Replay Buffer : i :  628
# Replay Buffer : i :  629
# Replay Buffer : i :  630
# Replay Buffer : i :  631
# Replay Buffer : i :  632
# Replay Buffer : i :  633
# Replay Buffer : i :  634
# Replay Buffer : i :  635
# Replay Buffer : i :  636
# Replay Buffer : i :  637
# Replay Buffer : i :  638
# Replay Buffer : i :  639
# Replay Buffer : i :  640
# Replay Buffer : i :  641
# Replay Buffer : i :  642
# Replay Buffer : i :  643
# Replay Buffer : i :  644
# Replay Buffer : i :  645
# Replay Buffer : i :  646
# Replay Buffer : i :  647
# Replay Buffer : i :  648
# Replay Buffer : i :  649
# Replay Buffer : i :  650
# Replay Buffer : i :  651
# Replay Buffer : i :  652
# Replay Buffer : i :  653
# Replay Buffer : i :  654
# Replay Buffer : i :  655
# Replay Buffer : i :  656
# Replay Buffer : i :  657
# Replay Buffer : i :  658
# Replay Buffer : i :  659
# Replay Buffer : i :  660
# Replay Buffer : i :  661
# Replay Buffer : i :  662
# Replay Buffer : i :  663
# Replay Buffer : i :  664
# Replay Buffer : i :  665
# Replay Buffer : i :  666
# Replay Buffer : i :  667
# Replay Buffer : i :  668
# Replay Buffer : i :  669
# Replay Buffer : i :  670
# Replay Buffer : i :  671
# Replay Buffer : i :  672
# Replay Buffer : i :  673
# Replay Buffer : i :  674
# Replay Buffer : i :  675
# Replay Buffer : i :  676
# Replay Buffer : i :  677
# Replay Buffer : i :  678
# Replay Buffer : i :  679
# Replay Buffer : i :  680
# Replay Buffer : i :  681
# Replay Buffer : i :  682
# Replay Buffer : i :  683
# Replay Buffer : i :  684
# Replay Buffer : i :  685
# Replay Buffer : i :  686
# Replay Buffer : i :  687
# Replay Buffer : i :  688
# Replay Buffer : i :  689
# Replay Buffer : i :  690
# Replay Buffer : i :  691
# Replay Buffer : i :  692
# Replay Buffer : i :  693
# Replay Buffer : i :  694
# Replay Buffer : i :  695
# Replay Buffer : i :  696
# Replay Buffer : i :  697
# Replay Buffer : i :  698
# Replay Buffer : i :  699
# Replay Buffer : i :  700
# Replay Buffer : i :  701
# Replay Buffer : i :  702
# Replay Buffer : i :  703
# Replay Buffer : i :  704
# Replay Buffer : i :  705
# Replay Buffer : i :  706
# Replay Buffer : i :  707
# Replay Buffer : i :  708
# Replay Buffer : i :  709
# Replay Buffer : i :  710
# Replay Buffer : i :  711
# Replay Buffer : i :  712
# Replay Buffer : i :  713
# Replay Buffer : i :  714
# Replay Buffer : i :  715
# Replay Buffer : i :  716
# Replay Buffer : i :  717
# Replay Buffer : i :  718
# Replay Buffer : i :  719
# Replay Buffer : i :  720
# Replay Buffer : i :  721
# Replay Buffer : i :  722
# Replay Buffer : i :  723
# Replay Buffer : i :  724
# Replay Buffer : i :  725
# Replay Buffer : i :  726
# Replay Buffer : i :  727
# Replay Buffer : i :  728
# Replay Buffer : i :  729
# Replay Buffer : i :  730
# Replay Buffer : i :  731
# Replay Buffer : i :  732
# Replay Buffer : i :  733
# Replay Buffer : i :  734
# Replay Buffer : i :  735
# Replay Buffer : i :  736
# Replay Buffer : i :  737
# Replay Buffer : i :  738
# Replay Buffer : i :  739
# Replay Buffer : i :  740
# Replay Buffer : i :  741
# Replay Buffer : i :  742
# Replay Buffer : i :  743
# Replay Buffer : i :  744
# Replay Buffer : i :  745
# Replay Buffer : i :  746
# Replay Buffer : i :  747
# Replay Buffer : i :  748
# Replay Buffer : i :  749
# Replay Buffer : i :  750
# Replay Buffer : i :  751
# Replay Buffer : i :  752
# Replay Buffer : i :  753
# Replay Buffer : i :  754
# Replay Buffer : i :  755
# Replay Buffer : i :  756
# Replay Buffer : i :  757
# Replay Buffer : i :  758
# Replay Buffer : i :  759
# Replay Buffer : i :  760
# Replay Buffer : i :  761
# Replay Buffer : i :  762
# Replay Buffer : i :  763
# Replay Buffer : i :  764
# Replay Buffer : i :  765
# Replay Buffer : i :  766
# Replay Buffer : i :  767
# Replay Buffer : i :  768
# Replay Buffer : i :  769
# Replay Buffer : i :  770
# Replay Buffer : i :  771
# Replay Buffer : i :  772
# Replay Buffer : i :  773
# Replay Buffer : i :  774
# Replay Buffer : i :  775
# Replay Buffer : i :  776
# Replay Buffer : i :  777
# Replay Buffer : i :  778
# Replay Buffer : i :  779
# Replay Buffer : i :  780
# Replay Buffer : i :  781
# Replay Buffer : i :  782
# Replay Buffer : i :  783
# Replay Buffer : i :  784
# Replay Buffer : i :  785
# Replay Buffer : i :  786
# Replay Buffer : i :  787
# Replay Buffer : i :  788
# Replay Buffer : i :  789
# Replay Buffer : i :  790
# Replay Buffer : i :  791
# Replay Buffer : i :  792
# Replay Buffer : i :  793
# Replay Buffer : i :  794
# Replay Buffer : i :  795
# Replay Buffer : i :  796
# Replay Buffer : i :  797
# Replay Buffer : i :  798
# Replay Buffer : i :  799
# Replay Buffer : i :  800
# Replay Buffer : i :  801
# Replay Buffer : i :  802
# Replay Buffer : i :  803
# Replay Buffer : i :  804
# Replay Buffer : i :  805
# Replay Buffer : i :  806
# Replay Buffer : i :  807
# Replay Buffer : i :  808
# Replay Buffer : i :  809
# Replay Buffer : i :  810
# Replay Buffer : i :  811
# Replay Buffer : i :  812
# Replay Buffer : i :  813
# Replay Buffer : i :  814
# Replay Buffer : i :  815
# Replay Buffer : i :  816
# Replay Buffer : i :  817
# Replay Buffer : i :  818
# Replay Buffer : i :  819
# Replay Buffer : i :  820
# Replay Buffer : i :  821
# Replay Buffer : i :  822
# Replay Buffer : i :  823
# Replay Buffer : i :  824
# Replay Buffer : i :  825
# Replay Buffer : i :  826
# Replay Buffer : i :  827
# Replay Buffer : i :  828
# Replay Buffer : i :  829
# Replay Buffer : i :  830
# Replay Buffer : i :  831
# Replay Buffer : i :  832
# Replay Buffer : i :  833
# Replay Buffer : i :  834
# Replay Buffer : i :  835
# Replay Buffer : i :  836
# Replay Buffer : i :  837
# Replay Buffer : i :  838
# Replay Buffer : i :  839
# Replay Buffer : i :  840
# Replay Buffer : i :  841
# Replay Buffer : i :  842
# Replay Buffer : i :  843
# Replay Buffer : i :  844
# Replay Buffer : i :  845
# Replay Buffer : i :  846
# Replay Buffer : i :  847
# Replay Buffer : i :  848
# Replay Buffer : i :  849
# Replay Buffer : i :  850
# Replay Buffer : i :  851
# Replay Buffer : i :  852
# Replay Buffer : i :  853
# Replay Buffer : i :  854
# Replay Buffer : i :  855
# Replay Buffer : i :  856
# Replay Buffer : i :  857
# Replay Buffer : i :  858
# Replay Buffer : i :  859
# Replay Buffer : i :  860
# Replay Buffer : i :  861
# Replay Buffer : i :  862
# Replay Buffer : i :  863
# Replay Buffer : i :  864
# Replay Buffer : i :  865
# Replay Buffer : i :  866
# Replay Buffer : i :  867
# Replay Buffer : i :  868
# Replay Buffer : i :  869
# Replay Buffer : i :  870
# Replay Buffer : i :  871
# Replay Buffer : i :  872
# Replay Buffer : i :  873
# Replay Buffer : i :  874
# Replay Buffer : i :  875
# Replay Buffer : i :  876
# Replay Buffer : i :  877
# Replay Buffer : i :  878
# Replay Buffer : i :  879
# Replay Buffer : i :  880
# Replay Buffer : i :  881
# Replay Buffer : i :  882
# Replay Buffer : i :  883
# Replay Buffer : i :  884
# Replay Buffer : i :  885
# Replay Buffer : i :  886
# Replay Buffer : i :  887
# Replay Buffer : i :  888
# Replay Buffer : i :  889
# Replay Buffer : i :  890
# Replay Buffer : i :  891
# Replay Buffer : i :  892
# Replay Buffer : i :  893
# Replay Buffer : i :  894
# Replay Buffer : i :  895
# Replay Buffer : i :  896
# Replay Buffer : i :  897
# Replay Buffer : i :  898
# Replay Buffer : i :  899
# Replay Buffer : i :  900
# Replay Buffer : i :  901
# Replay Buffer : i :  902
# Replay Buffer : i :  903
# Replay Buffer : i :  904
# Replay Buffer : i :  905
# Replay Buffer : i :  906
# Replay Buffer : i :  907
# Replay Buffer : i :  908
# Replay Buffer : i :  909
# Replay Buffer : i :  910
# Replay Buffer : i :  911
# Replay Buffer : i :  912
# Replay Buffer : i :  913
# Replay Buffer : i :  914
# Replay Buffer : i :  915
# Replay Buffer : i :  916
# Replay Buffer : i :  917
# Replay Buffer : i :  918
# Replay Buffer : i :  919
# Replay Buffer : i :  920
# Replay Buffer : i :  921
# Replay Buffer : i :  922
# Replay Buffer : i :  923
# Replay Buffer : i :  924
# Replay Buffer : i :  925
# Replay Buffer : i :  926
# Replay Buffer : i :  927
# Replay Buffer : i :  928
# Replay Buffer : i :  929
# Replay Buffer : i :  930
# Replay Buffer : i :  931
# Replay Buffer : i :  932
# Replay Buffer : i :  933
# Replay Buffer : i :  934
# Replay Buffer : i :  935
# Replay Buffer : i :  936
# Replay Buffer : i :  937
# Replay Buffer : i :  938
# Replay Buffer : i :  939
# Replay Buffer : i :  940
# Replay Buffer : i :  941
# Replay Buffer : i :  942
# Replay Buffer : i :  943
# Replay Buffer : i :  944
# Replay Buffer : i :  945
# Replay Buffer : i :  946
# Replay Buffer : i :  947
# Replay Buffer : i :  948
# Replay Buffer : i :  949
# Replay Buffer : i :  950
# Replay Buffer : i :  951
# Replay Buffer : i :  952
# Replay Buffer : i :  953
# Replay Buffer : i :  954
# Replay Buffer : i :  955
# Replay Buffer : i :  956
# Replay Buffer : i :  957
# Replay Buffer : i :  958
# Replay Buffer : i :  959
# Replay Buffer : i :  960
# Replay Buffer : i :  961
# Replay Buffer : i :  962
# Replay Buffer : i :  963
# Replay Buffer : i :  964
# Replay Buffer : i :  965
# Replay Buffer : i :  966
# Replay Buffer : i :  967
# Replay Buffer : i :  968
# Replay Buffer : i :  969
# Replay Buffer : i :  970
# Replay Buffer : i :  971
# Replay Buffer : i :  972
# Replay Buffer : i :  973
# Replay Buffer : i :  974
# Replay Buffer : i :  975
# Replay Buffer : i :  976
# Replay Buffer : i :  977
# Replay Buffer : i :  978
# Replay Buffer : i :  979
# Replay Buffer : i :  980
# Replay Buffer : i :  981
# Replay Buffer : i :  982
# Replay Buffer : i :  983
# Replay Buffer : i :  984
# Replay Buffer : i :  985
# Replay Buffer : i :  986
# Replay Buffer : i :  987
# Replay Buffer : i :  988
# Replay Buffer : i :  989
# Replay Buffer : i :  990
# Replay Buffer : i :  991
# Replay Buffer : i :  992
# Replay Buffer : i :  993
# Replay Buffer : i :  994
# Replay Buffer : i :  995
# Replay Buffer : i :  996
# Replay Buffer : i :  997
# Replay Buffer : i :  998
# Replay Buffer : i :  999
# Replay Buffer : i :  1000
# Replay Buffer : i :  1001
# Replay Buffer : i :  1002
# Replay Buffer : i :  1003
# Replay Buffer : i :  1004
# Replay Buffer : i :  1005
# Replay Buffer : i :  1006
# Replay Buffer : i :  1007
# Replay Buffer : i :  1008
# Replay Buffer : i :  1009
# Replay Buffer : i :  1010
# Replay Buffer : i :  1011
# Replay Buffer : i :  1012
# Replay Buffer : i :  1013
# Replay Buffer : i :  1014
# Replay Buffer : i :  1015
# Replay Buffer : i :  1016
# Replay Buffer : i :  1017
# Replay Buffer : i :  1018
# Replay Buffer : i :  1019
# Replay Buffer : i :  1020
# Replay Buffer : i :  1021
# Replay Buffer : i :  1022
# Replay Buffer : i :  1023
# Replay Buffer : i :  1024
# Replay Buffer : i :  1025
# Replay Buffer : i :  1026
# Replay Buffer : i :  1027
# Replay Buffer : i :  1028
# Replay Buffer : i :  1029
# Replay Buffer : i :  1030
# Replay Buffer : i :  1031
# Replay Buffer : i :  1032
# Replay Buffer : i :  1033
# Replay Buffer : i :  1034
# Replay Buffer : i :  1035
# Replay Buffer : i :  1036
# Replay Buffer : i :  1037
# Replay Buffer : i :  1038
# Replay Buffer : i :  1039
# Replay Buffer : i :  1040
# Replay Buffer : i :  1041
# Replay Buffer : i :  1042
# Replay Buffer : i :  1043
# Replay Buffer : i :  1044
# Replay Buffer : i :  1045
# Replay Buffer : i :  1046
# Replay Buffer : i :  1047
# Replay Buffer : i :  1048
# Replay Buffer : i :  1049
# Replay Buffer : i :  1050
# Replay Buffer : i :  1051
# Replay Buffer : i :  1052
# Replay Buffer : i :  1053
# Replay Buffer : i :  1054
# Replay Buffer : i :  1055
# Replay Buffer : i :  1056
# Replay Buffer : i :  1057
# Replay Buffer : i :  1058
# Replay Buffer : i :  1059
# Replay Buffer : i :  1060
# Replay Buffer : i :  1061
# Replay Buffer : i :  1062
# Replay Buffer : i :  1063
# Replay Buffer : i :  1064
# Replay Buffer : i :  1065
# Replay Buffer : i :  1066
# Replay Buffer : i :  1067
# Replay Buffer : i :  1068
# Replay Buffer : i :  1069
# Replay Buffer : i :  1070
# Replay Buffer : i :  1071
# Replay Buffer : i :  1072
# Replay Buffer : i :  1073
# Replay Buffer : i :  1074
# Replay Buffer : i :  1075
# Replay Buffer : i :  1076
# Replay Buffer : i :  1077
# Replay Buffer : i :  1078
# Replay Buffer : i :  1079
# Replay Buffer : i :  1080
# Replay Buffer : i :  1081
# Replay Buffer : i :  1082
# Replay Buffer : i :  1083
# Replay Buffer : i :  1084
# Replay Buffer : i :  1085
# Replay Buffer : i :  1086
# Replay Buffer : i :  1087
# Replay Buffer : i :  1088
# Replay Buffer : i :  1089
# Replay Buffer : i :  1090
# Replay Buffer : i :  1091
# Replay Buffer : i :  1092
# Replay Buffer : i :  1093
# Replay Buffer : i :  1094
# Replay Buffer : i :  1095
# Replay Buffer : i :  1096
# Replay Buffer : i :  1097
# Replay Buffer : i :  1098
# Replay Buffer : i :  1099
# Replay Buffer : i :  1100
# Replay Buffer : i :  1101
# Replay Buffer : i :  1102
# Replay Buffer : i :  1103
# Replay Buffer : i :  1104
# Replay Buffer : i :  1105
# Replay Buffer : i :  1106
# Replay Buffer : i :  1107
# Replay Buffer : i :  1108
# Replay Buffer : i :  1109
# Replay Buffer : i :  1110
# Replay Buffer : i :  1111
# Replay Buffer : i :  1112
# Replay Buffer : i :  1113
# Replay Buffer : i :  1114
# Replay Buffer : i :  1115
# Replay Buffer : i :  1116
# Replay Buffer : i :  1117
# Replay Buffer : i :  1118
# Replay Buffer : i :  1119
# Replay Buffer : i :  1120
# Replay Buffer : i :  1121
# Replay Buffer : i :  1122
# Replay Buffer : i :  1123
# Replay Buffer : i :  1124
# Replay Buffer : i :  1125
# Replay Buffer : i :  1126
# Replay Buffer : i :  1127
# Replay Buffer : i :  1128
# Replay Buffer : i :  1129
# Replay Buffer : i :  1130
# Replay Buffer : i :  1131
# Replay Buffer : i :  1132
# Replay Buffer : i :  1133
# Replay Buffer : i :  1134
# Replay Buffer : i :  1135
# Replay Buffer : i :  1136
# Replay Buffer : i :  1137
# Replay Buffer : i :  1138
# Replay Buffer : i :  1139
# Replay Buffer : i :  1140
# Replay Buffer : i :  1141
# Replay Buffer : i :  1142
# Replay Buffer : i :  1143
# Replay Buffer : i :  1144
# Replay Buffer : i :  1145
# Replay Buffer : i :  1146
# Replay Buffer : i :  1147
# Replay Buffer : i :  1148
# Replay Buffer : i :  1149
# Replay Buffer : i :  1150
# Replay Buffer : i :  1151
# Replay Buffer : i :  1152
# Replay Buffer : i :  1153
# Replay Buffer : i :  1154
# Replay Buffer : i :  1155
# Replay Buffer : i :  1156
# Replay Buffer : i :  1157
# Replay Buffer : i :  1158
# Replay Buffer : i :  1159
# Replay Buffer : i :  1160
# Replay Buffer : i :  1161
# Replay Buffer : i :  1162
# Replay Buffer : i :  1163
# Replay Buffer : i :  1164
# Replay Buffer : i :  1165
# Replay Buffer : i :  1166
# Replay Buffer : i :  1167
# Replay Buffer : i :  1168
# Replay Buffer : i :  1169
# Replay Buffer : i :  1170
# Replay Buffer : i :  1171
# Replay Buffer : i :  1172
# Replay Buffer : i :  1173
# Replay Buffer : i :  1174
# Replay Buffer : i :  1175
# Replay Buffer : i :  1176
# Replay Buffer : i :  1177
# Replay Buffer : i :  1178
# Replay Buffer : i :  1179
# Replay Buffer : i :  1180
# Replay Buffer : i :  1181
# Replay Buffer : i :  1182
# Replay Buffer : i :  1183
# Replay Buffer : i :  1184
# Replay Buffer : i :  1185
# Replay Buffer : i :  1186
# Replay Buffer : i :  1187
# Replay Buffer : i :  1188
# Replay Buffer : i :  1189
# Replay Buffer : i :  1190
# Replay Buffer : i :  1191
# Replay Buffer : i :  1192
# Replay Buffer : i :  1193
# Replay Buffer : i :  1194
# Replay Buffer : i :  1195
# Replay Buffer : i :  1196
# Replay Buffer : i :  1197
# Replay Buffer : i :  1198
# Replay Buffer : i :  1199
# Replay Buffer : i :  1200
# Replay Buffer : i :  1201
# Replay Buffer : i :  1202
# Replay Buffer : i :  1203
# Replay Buffer : i :  1204
# Replay Buffer : i :  1205
# Replay Buffer : i :  1206
# Replay Buffer : i :  1207
# Replay Buffer : i :  1208
# Replay Buffer : i :  1209
# Replay Buffer : i :  1210
# Replay Buffer : i :  1211
# Replay Buffer : i :  1212
# Replay Buffer : i :  1213
# Replay Buffer : i :  1214
# Replay Buffer : i :  1215
# Replay Buffer : i :  1216
# Replay Buffer : i :  1217
# Replay Buffer : i :  1218
# Replay Buffer : i :  1219
# Replay Buffer : i :  1220
# Replay Buffer : i :  1221
# Replay Buffer : i :  1222
# Replay Buffer : i :  1223
# Replay Buffer : i :  1224
# Replay Buffer : i :  1225
# Replay Buffer : i :  1226
# Replay Buffer : i :  1227
# Replay Buffer : i :  1228
# Replay Buffer : i :  1229
# Replay Buffer : i :  1230
# Replay Buffer : i :  1231
# Replay Buffer : i :  1232
# Replay Buffer : i :  1233
# Replay Buffer : i :  1234
# Replay Buffer : i :  1235
# Replay Buffer : i :  1236
# Replay Buffer : i :  1237
# Replay Buffer : i :  1238
# Replay Buffer : i :  1239
# Replay Buffer : i :  1240
# Replay Buffer : i :  1241
# Replay Buffer : i :  1242
# Replay Buffer : i :  1243
# Replay Buffer : i :  1244
# Replay Buffer : i :  1245
# Replay Buffer : i :  1246
# Replay Buffer : i :  1247
# Replay Buffer : i :  1248
# Replay Buffer : i :  1249
# Replay Buffer : i :  1250
# Replay Buffer : i :  1251
# Replay Buffer : i :  1252
# Replay Buffer : i :  1253
# Replay Buffer : i :  1254
# Replay Buffer : i :  1255
# Replay Buffer : i :  1256
# Replay Buffer : i :  1257
# Replay Buffer : i :  1258
# Replay Buffer : i :  1259
# Replay Buffer : i :  1260
# Replay Buffer : i :  1261
# Replay Buffer : i :  1262
# Replay Buffer : i :  1263
# Replay Buffer : i :  1264
# Replay Buffer : i :  1265
# Replay Buffer : i :  1266
# Replay Buffer : i :  1267
# Replay Buffer : i :  1268
# Replay Buffer : i :  1269
# Replay Buffer : i :  1270
# Replay Buffer : i :  1271
# Replay Buffer : i :  1272
# Replay Buffer : i :  1273
# Replay Buffer : i :  1274
# Replay Buffer : i :  1275
# Replay Buffer : i :  1276
# Replay Buffer : i :  1277
# Replay Buffer : i :  1278
# Replay Buffer : i :  1279
# Replay Buffer : i :  1280
# Replay Buffer : i :  1281
# Replay Buffer : i :  1282
# Replay Buffer : i :  1283
# Replay Buffer : i :  1284
# Replay Buffer : i :  1285
# Replay Buffer : i :  1286
# Replay Buffer : i :  1287
# Replay Buffer : i :  1288
# Replay Buffer : i :  1289
# Replay Buffer : i :  1290
# Replay Buffer : i :  1291
# Replay Buffer : i :  1292
# Replay Buffer : i :  1293
# Replay Buffer : i :  1294
# Replay Buffer : i :  1295
# Replay Buffer : i :  1296
# Replay Buffer : i :  1297
# Replay Buffer : i :  1298
# Replay Buffer : i :  1299
# Replay Buffer : i :  1300
# Replay Buffer : i :  1301
# Replay Buffer : i :  1302
# Replay Buffer : i :  1303
# Replay Buffer : i :  1304
# Replay Buffer : i :  1305
# Replay Buffer : i :  1306
# Replay Buffer : i :  1307
# Replay Buffer : i :  1308
# Replay Buffer : i :  1309
# Replay Buffer : i :  1310
# Replay Buffer : i :  1311
# Replay Buffer : i :  1312
# Replay Buffer : i :  1313
# Replay Buffer : i :  1314
# Replay Buffer : i :  1315
# Replay Buffer : i :  1316
# Replay Buffer : i :  1317
# Replay Buffer : i :  1318
# Replay Buffer : i :  1319
# Replay Buffer : i :  1320
# Replay Buffer : i :  1321
# Replay Buffer : i :  1322
# Replay Buffer : i :  1323
# Replay Buffer : i :  1324
# Replay Buffer : i :  1325
# Replay Buffer : i :  1326
# Replay Buffer : i :  1327
# Replay Buffer : i :  1328
# Replay Buffer : i :  1329
# Replay Buffer : i :  1330
# Replay Buffer : i :  1331
# Replay Buffer : i :  1332
# Replay Buffer : i :  1333
# Replay Buffer : i :  1334
# Replay Buffer : i :  1335
# Replay Buffer : i :  1336
# Replay Buffer : i :  1337
# Replay Buffer : i :  1338
# Replay Buffer : i :  1339
# Replay Buffer : i :  1340
# Replay Buffer : i :  1341
# Replay Buffer : i :  1342
# Replay Buffer : i :  1343
# Replay Buffer : i :  1344
# Replay Buffer : i :  1345
# Replay Buffer : i :  1346
# Replay Buffer : i :  1347
# Replay Buffer : i :  1348
# Replay Buffer : i :  1349
# Replay Buffer : i :  1350
# Replay Buffer : i :  1351
# Replay Buffer : i :  1352
# Replay Buffer : i :  1353
# Replay Buffer : i :  1354
# Replay Buffer : i :  1355
# Replay Buffer : i :  1356
# Replay Buffer : i :  1357
# Replay Buffer : i :  1358
# Replay Buffer : i :  1359
# Replay Buffer : i :  1360
# Replay Buffer : i :  1361
# Replay Buffer : i :  1362
# Replay Buffer : i :  1363
# Replay Buffer : i :  1364
# Replay Buffer : i :  1365
# Replay Buffer : i :  1366
# Replay Buffer : i :  1367
# Replay Buffer : i :  1368
# Replay Buffer : i :  1369
# Replay Buffer : i :  1370
# Replay Buffer : i :  1371
# Replay Buffer : i :  1372
# Replay Buffer : i :  1373
# Replay Buffer : i :  1374
# Replay Buffer : i :  1375
# Replay Buffer : i :  1376
# Replay Buffer : i :  1377
# Replay Buffer : i :  1378
# Replay Buffer : i :  1379
# Replay Buffer : i :  1380
# Replay Buffer : i :  1381
# Replay Buffer : i :  1382
# Replay Buffer : i :  1383
# Replay Buffer : i :  1384
# Replay Buffer : i :  1385
# Replay Buffer : i :  1386
# Replay Buffer : i :  1387
# Replay Buffer : i :  1388
# Replay Buffer : i :  1389
# Replay Buffer : i :  1390
# Replay Buffer : i :  1391
# Replay Buffer : i :  1392
# Replay Buffer : i :  1393
# Replay Buffer : i :  1394
# Replay Buffer : i :  1395
# Replay Buffer : i :  1396
# Replay Buffer : i :  1397
# Replay Buffer : i :  1398
# Replay Buffer : i :  1399
# Replay Buffer : i :  1400
# Replay Buffer : i :  1401
# Replay Buffer : i :  1402
# Replay Buffer : i :  1403
# Replay Buffer : i :  1404
# Replay Buffer : i :  1405
# Replay Buffer : i :  1406
# Replay Buffer : i :  1407
# Replay Buffer : i :  1408
# Replay Buffer : i :  1409
# Replay Buffer : i :  1410
# Replay Buffer : i :  1411
# Replay Buffer : i :  1412
# Replay Buffer : i :  1413
# Replay Buffer : i :  1414
# Replay Buffer : i :  1415
# Replay Buffer : i :  1416
# Replay Buffer : i :  1417
# Replay Buffer : i :  1418
# Replay Buffer : i :  1419
# Replay Buffer : i :  1420
# Replay Buffer : i :  1421
# Replay Buffer : i :  1422
# Replay Buffer : i :  1423
# Replay Buffer : i :  1424
# Replay Buffer : i :  1425
# Replay Buffer : i :  1426
# Replay Buffer : i :  1427
# Replay Buffer : i :  1428
# Replay Buffer : i :  1429
# Replay Buffer : i :  1430
# Replay Buffer : i :  1431
# Replay Buffer : i :  1432
# Replay Buffer : i :  1433
# Replay Buffer : i :  1434
# Replay Buffer : i :  1435
# Replay Buffer : i :  1436
# Replay Buffer : i :  1437
# Replay Buffer : i :  1438
# Replay Buffer : i :  1439
# Replay Buffer : i :  1440
# Replay Buffer : i :  1441
# Replay Buffer : i :  1442
# Replay Buffer : i :  1443
# Replay Buffer : i :  1444
# Replay Buffer : i :  1445
# Replay Buffer : i :  1446
# Replay Buffer : i :  1447
# Replay Buffer : i :  1448
# Replay Buffer : i :  1449
# Replay Buffer : i :  1450
# Replay Buffer : i :  1451
# Replay Buffer : i :  1452
# Replay Buffer : i :  1453
# Replay Buffer : i :  1454
# Replay Buffer : i :  1455
# Replay Buffer : i :  1456
# Replay Buffer : i :  1457
# Replay Buffer : i :  1458
# Replay Buffer : i :  1459
# Replay Buffer : i :  1460
# Replay Buffer : i :  1461
# Replay Buffer : i :  1462
# Replay Buffer : i :  1463
# Replay Buffer : i :  1464
# Replay Buffer : i :  1465
# Replay Buffer : i :  1466
# Replay Buffer : i :  1467
# Replay Buffer : i :  1468
# Replay Buffer : i :  1469
# Replay Buffer : i :  1470
# Replay Buffer : i :  1471
# Replay Buffer : i :  1472
# Replay Buffer : i :  1473
# Replay Buffer : i :  1474
# Replay Buffer : i :  1475
# Replay Buffer : i :  1476
# Replay Buffer : i :  1477
# Replay Buffer : i :  1478
# Replay Buffer : i :  1479
# Replay Buffer : i :  1480
# Replay Buffer : i :  1481
# Replay Buffer : i :  1482
# Replay Buffer : i :  1483
# Replay Buffer : i :  1484
# Replay Buffer : i :  1485
# Replay Buffer : i :  1486
# Replay Buffer : i :  1487
# Replay Buffer : i :  1488
# Replay Buffer : i :  1489
# Replay Buffer : i :  1490
# Replay Buffer : i :  1491
# Replay Buffer : i :  1492
# Replay Buffer : i :  1493
# Replay Buffer : i :  1494
# Replay Buffer : i :  1495
# Replay Buffer : i :  1496
# Replay Buffer : i :  1497
# Replay Buffer : i :  1498
# Replay Buffer : i :  1499
# Replay Buffer : i :  1500
# Replay Buffer : i :  1501
# Replay Buffer : i :  1502
# Replay Buffer : i :  1503
# Replay Buffer : i :  1504
# Replay Buffer : i :  1505
# Replay Buffer : i :  1506
# Replay Buffer : i :  1507
# Replay Buffer : i :  1508
# Replay Buffer : i :  1509
# Replay Buffer : i :  1510
# Replay Buffer : i :  1511
# Replay Buffer : i :  1512
# Replay Buffer : i :  1513
# Replay Buffer : i :  1514
# Replay Buffer : i :  1515
# Replay Buffer : i :  1516
# Replay Buffer : i :  1517
# Replay Buffer : i :  1518
# Replay Buffer : i :  1519
# Replay Buffer : i :  1520
# Replay Buffer : i :  1521
# Replay Buffer : i :  1522
# Replay Buffer : i :  1523
# Replay Buffer : i :  1524
# Replay Buffer : i :  1525
# Replay Buffer : i :  1526
# Replay Buffer : i :  1527
# Replay Buffer : i :  1528
# Replay Buffer : i :  1529
# Replay Buffer : i :  1530
# Replay Buffer : i :  1531
# Replay Buffer : i :  1532
# Replay Buffer : i :  1533
# Replay Buffer : i :  1534
# Replay Buffer : i :  1535
# Replay Buffer : i :  1536
# Replay Buffer : i :  1537
# Replay Buffer : i :  1538
# Replay Buffer : i :  1539
# Replay Buffer : i :  1540
# Replay Buffer : i :  1541
# Replay Buffer : i :  1542
# Replay Buffer : i :  1543
# Replay Buffer : i :  1544
# Replay Buffer : i :  1545
# Replay Buffer : i :  1546
# Replay Buffer : i :  1547
# Replay Buffer : i :  1548
# Replay Buffer : i :  1549
# Replay Buffer : i :  1550
# Replay Buffer : i :  1551
# Replay Buffer : i :  1552
# Replay Buffer : i :  1553
# Replay Buffer : i :  1554
# Replay Buffer : i :  1555
# Replay Buffer : i :  1556
# Replay Buffer : i :  1557
# Replay Buffer : i :  1558
# Replay Buffer : i :  1559
# Replay Buffer : i :  1560
# Replay Buffer : i :  1561
# Replay Buffer : i :  1562
# Replay Buffer : i :  1563
# Replay Buffer : i :  1564
# Replay Buffer : i :  1565
# Replay Buffer : i :  1566
# Replay Buffer : i :  1567
# Replay Buffer : i :  1568
# Replay Buffer : i :  1569
# Replay Buffer : i :  1570
# Replay Buffer : i :  1571
# Replay Buffer : i :  1572
# Replay Buffer : i :  1573
# Replay Buffer : i :  1574
# Replay Buffer : i :  1575
# Replay Buffer : i :  1576
# Replay Buffer : i :  1577
# Replay Buffer : i :  1578
# Replay Buffer : i :  1579
# Replay Buffer : i :  1580
# Replay Buffer : i :  1581
# Replay Buffer : i :  1582
# Replay Buffer : i :  1583
# Replay Buffer : i :  1584
# Replay Buffer : i :  1585
# Replay Buffer : i :  1586
# Replay Buffer : i :  1587
# Replay Buffer : i :  1588
# Replay Buffer : i :  1589
# Replay Buffer : i :  1590
# Replay Buffer : i :  1591
# Replay Buffer : i :  1592
# Replay Buffer : i :  1593
# Replay Buffer : i :  1594
# Replay Buffer : i :  1595
# Replay Buffer : i :  1596
# Replay Buffer : i :  1597
# Replay Buffer : i :  1598
# Replay Buffer : i :  1599
# Replay Buffer : i :  1600
# Replay Buffer : i :  1601
# Replay Buffer : i :  1602
# Replay Buffer : i :  1603
# Replay Buffer : i :  1604
# Replay Buffer : i :  1605
# Replay Buffer : i :  1606
# Replay Buffer : i :  1607
# Replay Buffer : i :  1608
# Replay Buffer : i :  1609
# Replay Buffer : i :  1610
# Replay Buffer : i :  1611
# Replay Buffer : i :  1612
# Replay Buffer : i :  1613
# Replay Buffer : i :  1614
# Replay Buffer : i :  1615
# Replay Buffer : i :  1616
# Replay Buffer : i :  1617
# Replay Buffer : i :  1618
# Replay Buffer : i :  1619
# Replay Buffer : i :  1620
# Replay Buffer : i :  1621
# Replay Buffer : i :  1622
# Replay Buffer : i :  1623
# Replay Buffer : i :  1624
# Replay Buffer : i :  1625
# Replay Buffer : i :  1626
# Replay Buffer : i :  1627
# Replay Buffer : i :  1628
# Replay Buffer : i :  1629
# Replay Buffer : i :  1630
# Replay Buffer : i :  1631
# Replay Buffer : i :  1632
# Replay Buffer : i :  1633
# Replay Buffer : i :  1634
# Replay Buffer : i :  1635
# Replay Buffer : i :  1636
# Replay Buffer : i :  1637
# Replay Buffer : i :  1638
# Replay Buffer : i :  1639
# Replay Buffer : i :  1640
# Replay Buffer : i :  1641
# Replay Buffer : i :  1642
# Replay Buffer : i :  1643
# Replay Buffer : i :  1644
# Replay Buffer : i :  1645
# Replay Buffer : i :  1646
# Replay Buffer : i :  1647
# Replay Buffer : i :  1648
# Replay Buffer : i :  1649
# Replay Buffer : i :  1650
# Replay Buffer : i :  1651
# Replay Buffer : i :  1652
# Replay Buffer : i :  1653
# Replay Buffer : i :  1654
# Replay Buffer : i :  1655
# Replay Buffer : i :  1656
# Replay Buffer : i :  1657
# Replay Buffer : i :  1658
# Replay Buffer : i :  1659
# Replay Buffer : i :  1660
# Replay Buffer : i :  1661
# Replay Buffer : i :  1662
# Replay Buffer : i :  1663
# Replay Buffer : i :  1664
# Replay Buffer : i :  1665
# Replay Buffer : i :  1666
# Replay Buffer : i :  1667
# Replay Buffer : i :  1668
# Replay Buffer : i :  1669
# Replay Buffer : i :  1670
# Replay Buffer : i :  1671
# Replay Buffer : i :  1672
# Replay Buffer : i :  1673
# Replay Buffer : i :  1674
# Replay Buffer : i :  1675
# Replay Buffer : i :  1676
# Replay Buffer : i :  1677
# Replay Buffer : i :  1678
# Replay Buffer : i :  1679
# Replay Buffer : i :  1680
# Replay Buffer : i :  1681
# Replay Buffer : i :  1682
# Replay Buffer : i :  1683
# Replay Buffer : i :  1684
# Replay Buffer : i :  1685
# Replay Buffer : i :  1686
# Replay Buffer : i :  1687
# Replay Buffer : i :  1688
# Replay Buffer : i :  1689
# Replay Buffer : i :  1690
# Replay Buffer : i :  1691
# Replay Buffer : i :  1692
# Replay Buffer : i :  1693
# Replay Buffer : i :  1694
# Replay Buffer : i :  1695
# Replay Buffer : i :  1696
# Replay Buffer : i :  1697
# Replay Buffer : i :  1698
# Replay Buffer : i :  1699
# Replay Buffer : i :  1700
# Replay Buffer : i :  1701
# Replay Buffer : i :  1702
# Replay Buffer : i :  1703
# Replay Buffer : i :  1704
# Replay Buffer : i :  1705
# Replay Buffer : i :  1706
# Replay Buffer : i :  1707
# Replay Buffer : i :  1708
# Replay Buffer : i :  1709
# Replay Buffer : i :  1710
# Replay Buffer : i :  1711
# Replay Buffer : i :  1712
# Replay Buffer : i :  1713
# Replay Buffer : i :  1714
# Replay Buffer : i :  1715
# Replay Buffer : i :  1716
# Replay Buffer : i :  1717
# Replay Buffer : i :  1718
# Replay Buffer : i :  1719
# Replay Buffer : i :  1720
# Replay Buffer : i :  1721
# Replay Buffer : i :  1722
# Replay Buffer : i :  1723
# Replay Buffer : i :  1724
# Replay Buffer : i :  1725
# Replay Buffer : i :  1726
# Replay Buffer : i :  1727
# Replay Buffer : i :  1728
# Replay Buffer : i :  1729
# Replay Buffer : i :  1730
# Replay Buffer : i :  1731
# Replay Buffer : i :  1732
# Replay Buffer : i :  1733
# Replay Buffer : i :  1734
# Replay Buffer : i :  1735
# Replay Buffer : i :  1736
# Replay Buffer : i :  1737
# Replay Buffer : i :  1738
# Replay Buffer : i :  1739
# Replay Buffer : i :  1740
# Replay Buffer : i :  1741
# Replay Buffer : i :  1742
# Replay Buffer : i :  1743
# Replay Buffer : i :  1744
# Replay Buffer : i :  1745
# Replay Buffer : i :  1746
# Replay Buffer : i :  1747
# Replay Buffer : i :  1748
# Replay Buffer : i :  1749
# Replay Buffer : i :  1750
# Replay Buffer : i :  1751
# Replay Buffer : i :  1752
# Replay Buffer : i :  1753
# Replay Buffer : i :  1754
# Replay Buffer : i :  1755
# Replay Buffer : i :  1756
# Replay Buffer : i :  1757
# Replay Buffer : i :  1758
# Replay Buffer : i :  1759
# Replay Buffer : i :  1760
# Replay Buffer : i :  1761
# Replay Buffer : i :  1762
# Replay Buffer : i :  1763
# Replay Buffer : i :  1764
# Replay Buffer : i :  1765
# Replay Buffer : i :  1766
# Replay Buffer : i :  1767
# Replay Buffer : i :  1768
# Replay Buffer : i :  1769
# Replay Buffer : i :  1770
# Replay Buffer : i :  1771
# Replay Buffer : i :  1772
# Replay Buffer : i :  1773
# Replay Buffer : i :  1774
# Replay Buffer : i :  1775
# Replay Buffer : i :  1776
# Replay Buffer : i :  1777
# Replay Buffer : i :  1778
# Replay Buffer : i :  1779
# Replay Buffer : i :  1780
# Replay Buffer : i :  1781
# Replay Buffer : i :  1782
# Replay Buffer : i :  1783
# Replay Buffer : i :  1784
# Replay Buffer : i :  1785
# Replay Buffer : i :  1786
# Replay Buffer : i :  1787
# Replay Buffer : i :  1788
# Replay Buffer : i :  1789
# Replay Buffer : i :  1790
# Replay Buffer : i :  1791
# Replay Buffer : i :  1792
# Replay Buffer : i :  1793
# Replay Buffer : i :  1794
# Replay Buffer : i :  1795
# Replay Buffer : i :  1796
# Replay Buffer : i :  1797
# Replay Buffer : i :  1798
# Replay Buffer : i :  1799
# Replay Buffer : i :  1800
# Replay Buffer : i :  1801
# Replay Buffer : i :  1802
# Replay Buffer : i :  1803
# Replay Buffer : i :  1804
# Replay Buffer : i :  1805
# Replay Buffer : i :  1806
# Replay Buffer : i :  1807
# Replay Buffer : i :  1808
# Replay Buffer : i :  1809
# Replay Buffer : i :  1810
# Replay Buffer : i :  1811
# Replay Buffer : i :  1812
# Replay Buffer : i :  1813
# Replay Buffer : i :  1814
# Replay Buffer : i :  1815
# Replay Buffer : i :  1816
# Replay Buffer : i :  1817
# Replay Buffer : i :  1818
# Replay Buffer : i :  1819
# Replay Buffer : i :  1820
# Replay Buffer : i :  1821
# Replay Buffer : i :  1822
# Replay Buffer : i :  1823
# Replay Buffer : i :  1824
# Replay Buffer : i :  1825
# Replay Buffer : i :  1826
# Replay Buffer : i :  1827
# Replay Buffer : i :  1828
# Replay Buffer : i :  1829
# Replay Buffer : i :  1830
# Replay Buffer : i :  1831
# Replay Buffer : i :  1832
# Replay Buffer : i :  1833
# Replay Buffer : i :  1834
# Replay Buffer : i :  1835
# Replay Buffer : i :  1836
# Replay Buffer : i :  1837
# Replay Buffer : i :  1838
# Replay Buffer : i :  1839
# Replay Buffer : i :  1840
# Replay Buffer : i :  1841
# Replay Buffer : i :  1842
# Replay Buffer : i :  1843
# Replay Buffer : i :  1844
# Replay Buffer : i :  1845
# Replay Buffer : i :  1846
# Replay Buffer : i :  1847
# Replay Buffer : i :  1848
# Replay Buffer : i :  1849
# Replay Buffer : i :  1850
# Replay Buffer : i :  1851
# Replay Buffer : i :  1852
# Replay Buffer : i :  1853
# Replay Buffer : i :  1854
# Replay Buffer : i :  1855
# Replay Buffer : i :  1856
# Replay Buffer : i :  1857
# Replay Buffer : i :  1858
# Replay Buffer : i :  1859
# Replay Buffer : i :  1860
# Replay Buffer : i :  1861
# Replay Buffer : i :  1862
# Replay Buffer : i :  1863
# Replay Buffer : i :  1864
# Replay Buffer : i :  1865
# Replay Buffer : i :  1866
# Replay Buffer : i :  1867
# Replay Buffer : i :  1868
# Replay Buffer : i :  1869
# Replay Buffer : i :  1870
# Replay Buffer : i :  1871
# Replay Buffer : i :  1872
# Replay Buffer : i :  1873
# Replay Buffer : i :  1874
# Replay Buffer : i :  1875
# Replay Buffer : i :  1876
# Replay Buffer : i :  1877
# Replay Buffer : i :  1878
# Replay Buffer : i :  1879
# Replay Buffer : i :  1880
# Replay Buffer : i :  1881
# Replay Buffer : i :  1882
# Replay Buffer : i :  1883
# Replay Buffer : i :  1884
# Replay Buffer : i :  1885
# Replay Buffer : i :  1886
# Replay Buffer : i :  1887
# ...
# Replay Buffer : i :  3385
# Replay Buffer : i :  3386
# Replay Buffer : i :  3387
# Replay Buffer : i :  3388
# Replay Buffer : i :  3389
# Replay Buffer : i :  3390
# Replay Buffer : i :  3391
# Replay Buffer : i :  3392
# Replay Buffer : i :  3393
# Replay Buffer : i :  3394
# Replay Buffer : i :  3395
# Replay Buffer : i :  3396
# Replay Buffer : i :  3397
# Replay Buffer : i :  3398
# Replay Buffer : i :  3399
# Replay Buffer : i :  3400
# Replay Buffer : i :  3401
# Replay Buffer : i :  3402
# Replay Buffer : i :  3403
# Replay Buffer : i :  3404
# Replay Buffer : i :  3405
# Replay Buffer : i :  3406
# Replay Buffer : i :  3407
# Replay Buffer : i :  3408
# Replay Buffer : i :  3409
# Replay Buffer : i :  3410
# Replay Buffer : i :  3411
# Replay Buffer : i :  3412
# Replay Buffer : i :  3413
# Replay Buffer : i :  3414
# Replay Buffer : i :  3415
# Replay Buffer : i :  3416
# Replay Buffer : i :  3417
# Replay Buffer : i :  3418
# Replay Buffer : i :  3419
# Replay Buffer : i :  3420
# Replay Buffer : i :  3421
# Replay Buffer : i :  3422
# Replay Buffer : i :  3423
# Replay Buffer : i :  3424
# Replay Buffer : i :  3425
# Replay Buffer : i :  3426
# Replay Buffer : i :  3427
# Replay Buffer : i :  3428
# Replay Buffer : i :  3429
# Replay Buffer : i :  3430
# Replay Buffer : i :  3431
# Replay Buffer : i :  3432
# Replay Buffer : i :  3433
# Replay Buffer : i :  3434
# Replay Buffer : i :  3435
# Replay Buffer : i :  3436
# Replay Buffer : i :  3437
# Replay Buffer : i :  3438
# Replay Buffer : i :  3439
# Replay Buffer : i :  3440
# Replay Buffer : i :  3441
# Replay Buffer : i :  3442
# Replay Buffer : i :  3443
# Replay Buffer : i :  3444
# Replay Buffer : i :  3445
# Replay Buffer : i :  3446
# Replay Buffer : i :  3447
# Replay Buffer : i :  3448
# Replay Buffer : i :  3449
# Replay Buffer : i :  3450
# Replay Buffer : i :  3451
# Replay Buffer : i :  3452
# Replay Buffer : i :  3453
# Replay Buffer : i :  3454
# Replay Buffer : i :  3455
# Replay Buffer : i :  3456
# Replay Buffer : i :  3457
# Replay Buffer : i :  3458
# Replay Buffer : i :  3459
# Replay Buffer : i :  3460
# Replay Buffer : i :  3461
# Replay Buffer : i :  3462
# Replay Buffer : i :  3463
# Replay Buffer : i :  3464
# Replay Buffer : i :  3465
# Replay Buffer : i :  3466
# Replay Buffer : i :  3467
# Replay Buffer : i :  3468
# Replay Buffer : i :  3469
# Replay Buffer : i :  3470
# Replay Buffer : i :  3471
# Replay Buffer : i :  3472
# Replay Buffer : i :  3473
# Replay Buffer : i :  3474
# Replay Buffer : i :  3475
# Replay Buffer : i :  3476
# Replay Buffer : i :  3477
# Replay Buffer : i :  3478
# Replay Buffer : i :  3479
# Replay Buffer : i :  3480
# Replay Buffer : i :  3481
# Replay Buffer : i :  3482
# Replay Buffer : i :  3483
# Replay Buffer : i :  3484
# Replay Buffer : i :  3485
# Replay Buffer : i :  3486
# Replay Buffer : i :  3487
# Replay Buffer : i :  3488
# Replay Buffer : i :  3489
# Replay Buffer : i :  3490
# Replay Buffer : i :  3491
# Replay Buffer : i :  3492
# Replay Buffer : i :  3493
# Replay Buffer : i :  3494
# Replay Buffer : i :  3495
# Replay Buffer : i :  3496
# Replay Buffer : i :  3497
# Replay Buffer : i :  3498
# Replay Buffer : i :  3499
# Replay Buffer : i :  3500
# Replay Buffer : i :  3501
# Replay Buffer : i :  3502
# Replay Buffer : i :  3503
# Replay Buffer : i :  3504
# Replay Buffer : i :  3505
# Replay Buffer : i :  3506
# Replay Buffer : i :  3507
# Replay Buffer : i :  3508
# Replay Buffer : i :  3509
# Replay Buffer : i :  3510
# Replay Buffer : i :  3511
# Replay Buffer : i :  3512
# Replay Buffer : i :  3513
# Replay Buffer : i :  3514
# Replay Buffer : i :  3515
# Replay Buffer : i :  3516
# Replay Buffer : i :  3517
# Replay Buffer : i :  3518
# Replay Buffer : i :  3519
# Replay Buffer : i :  3520
# Replay Buffer : i :  3521
# Replay Buffer : i :  3522
# Replay Buffer : i :  3523
# Replay Buffer : i :  3524
# Replay Buffer : i :  3525
# Replay Buffer : i :  3526
# Replay Buffer : i :  3527
# Replay Buffer : i :  3528
# Replay Buffer : i :  3529
# Replay Buffer : i :  3530
# Replay Buffer : i :  3531
# Replay Buffer : i :  3532
# Replay Buffer : i :  3533
# Replay Buffer : i :  3534
# Replay Buffer : i :  3535
# Replay Buffer : i :  3536
# Replay Buffer : i :  3537
# Replay Buffer : i :  3538
# Replay Buffer : i :  3539
# Replay Buffer : i :  3540
# Replay Buffer : i :  3541
# Replay Buffer : i :  3542
# Replay Buffer : i :  3543
# Replay Buffer : i :  3544
# Replay Buffer : i :  3545
# Replay Buffer : i :  3546
# Replay Buffer : i :  3547
# Replay Buffer : i :  3548
# Replay Buffer : i :  3549
# Replay Buffer : i :  3550
# Replay Buffer : i :  3551
# Replay Buffer : i :  3552
# Replay Buffer : i :  3553
# Replay Buffer : i :  3554
# Replay Buffer : i :  3555
# Replay Buffer : i :  3556
# Replay Buffer : i :  3557
# Replay Buffer : i :  3558
# Replay Buffer : i :  3559
# Replay Buffer : i :  3560
# Replay Buffer : i :  3561
# Replay Buffer : i :  3562
# Replay Buffer : i :  3563
# Replay Buffer : i :  3564
# Replay Buffer : i :  3565
# Replay Buffer : i :  3566
# Replay Buffer : i :  3567
# Replay Buffer : i :  3568
# Replay Buffer : i :  3569
# Replay Buffer : i :  3570
# Replay Buffer : i :  3571
# Replay Buffer : i :  3572
# Replay Buffer : i :  3573
# Replay Buffer : i :  3574
# Replay Buffer : i :  3575
# Replay Buffer : i :  3576
# Replay Buffer : i :  3577
# Replay Buffer : i :  3578
# Replay Buffer : i :  3579
# Replay Buffer : i :  3580
# Replay Buffer : i :  3581
# Replay Buffer : i :  3582
# Replay Buffer : i :  3583
# Replay Buffer : i :  3584
# Replay Buffer : i :  3585
# Replay Buffer : i :  3586
# Replay Buffer : i :  3587
# Replay Buffer : i :  3588
# Replay Buffer : i :  3589
# Replay Buffer : i :  3590
# Replay Buffer : i :  3591
# Replay Buffer : i :  3592
# Replay Buffer : i :  3593
# Replay Buffer : i :  3594
# Replay Buffer : i :  3595
# Replay Buffer : i :  3596
# Replay Buffer : i :  3597
# Replay Buffer : i :  3598
# Replay Buffer : i :  3599
# Replay Buffer : i :  3600
# Replay Buffer : i :  3601
# Replay Buffer : i :  3602
# Replay Buffer : i :  3603
# Replay Buffer : i :  3604
# Replay Buffer : i :  3605
# Replay Buffer : i :  3606
# Replay Buffer : i :  3607
# Replay Buffer : i :  3608
# Replay Buffer : i :  3609
# Replay Buffer : i :  3610
# Replay Buffer : i :  3611
# Replay Buffer : i :  3612
# Replay Buffer : i :  3613
# Replay Buffer : i :  3614
# Replay Buffer : i :  3615
# Replay Buffer : i :  3616
# Replay Buffer : i :  3617
# Replay Buffer : i :  3618
# Replay Buffer : i :  3619
# Replay Buffer : i :  3620
# Replay Buffer : i :  3621
# Replay Buffer : i :  3622
# Replay Buffer : i :  3623
# Replay Buffer : i :  3624
# Replay Buffer : i :  3625
# Replay Buffer : i :  3626
# Replay Buffer : i :  3627
# Replay Buffer : i :  3628
# Replay Buffer : i :  3629
# Replay Buffer : i :  3630
# Replay Buffer : i :  3631
# Replay Buffer : i :  3632
# Replay Buffer : i :  3633
# Replay Buffer : i :  3634
# Replay Buffer : i :  3635
# Replay Buffer : i :  3636
# Replay Buffer : i :  3637
# Replay Buffer : i :  3638
# Replay Buffer : i :  3639
# Replay Buffer : i :  3640
# Replay Buffer : i :  3641
# Replay Buffer : i :  3642
# Replay Buffer : i :  3643
# Replay Buffer : i :  3644
# Replay Buffer : i :  3645
# Replay Buffer : i :  3646
# Replay Buffer : i :  3647
# Replay Buffer : i :  3648
# Replay Buffer : i :  3649
# Replay Buffer : i :  3650
# Replay Buffer : i :  3651
# Replay Buffer : i :  3652
# Replay Buffer : i :  3653
# Replay Buffer : i :  3654
# Replay Buffer : i :  3655
# Replay Buffer : i :  3656
# Replay Buffer : i :  3657
# Replay Buffer : i :  3658
# Replay Buffer : i :  3659
# Replay Buffer : i :  3660
# Replay Buffer : i :  3661
# Replay Buffer : i :  3662
# Replay Buffer : i :  3663
# Replay Buffer : i :  3664
# Replay Buffer : i :  3665
# Replay Buffer : i :  3666
# Replay Buffer : i :  3667
# Replay Buffer : i :  3668
# Replay Buffer : i :  3669
# Replay Buffer : i :  3670
# Replay Buffer : i :  3671
# Replay Buffer : i :  3672
# Replay Buffer : i :  3673
# Replay Buffer : i :  3674
# Replay Buffer : i :  3675
# Replay Buffer : i :  3676
# Replay Buffer : i :  3677
# Replay Buffer : i :  3678
# Replay Buffer : i :  3679
# Replay Buffer : i :  3680
# Replay Buffer : i :  3681
# Replay Buffer : i :  3682
# Replay Buffer : i :  3683
# Replay Buffer : i :  3684
# Replay Buffer : i :  3685
# Replay Buffer : i :  3686
# Replay Buffer : i :  3687
# Replay Buffer : i :  3688
# Replay Buffer : i :  3689
# Replay Buffer : i :  3690
# Replay Buffer : i :  3691
# Replay Buffer : i :  3692
# Replay Buffer : i :  3693
# Replay Buffer : i :  3694
# Replay Buffer : i :  3695
# Replay Buffer : i :  3696
# Replay Buffer : i :  3697
# Replay Buffer : i :  3698
# Replay Buffer : i :  3699
# Replay Buffer : i :  3700
# Replay Buffer : i :  3701
# Replay Buffer : i :  3702
# Replay Buffer : i :  3703
# Replay Buffer : i :  3704
# Replay Buffer : i :  3705
# Replay Buffer : i :  3706
# Replay Buffer : i :  3707
# Replay Buffer : i :  3708
# Replay Buffer : i :  3709
# Replay Buffer : i :  3710
# Replay Buffer : i :  3711
# Replay Buffer : i :  3712
# Replay Buffer : i :  3713
# Replay Buffer : i :  3714
# Replay Buffer : i :  3715
# Replay Buffer : i :  3716
# Replay Buffer : i :  3717
# Replay Buffer : i :  3718
# Replay Buffer : i :  3719
# Replay Buffer : i :  3720
# Replay Buffer : i :  3721
# Replay Buffer : i :  3722
# Replay Buffer : i :  3723
# Replay Buffer : i :  3724
# Replay Buffer : i :  3725
# Replay Buffer : i :  3726
# Replay Buffer : i :  3727
# Replay Buffer : i :  3728
# Replay Buffer : i :  3729
# Replay Buffer : i :  3730
# Replay Buffer : i :  3731
# Replay Buffer : i :  3732
# Replay Buffer : i :  3733
# Replay Buffer : i :  3734
# Replay Buffer : i :  3735
# Replay Buffer : i :  3736
# Replay Buffer : i :  3737
# Replay Buffer : i :  3738
# Replay Buffer : i :  3739
# Replay Buffer : i :  3740
# Replay Buffer : i :  3741
# Replay Buffer : i :  3742
# Replay Buffer : i :  3743
# Replay Buffer : i :  3744
# Replay Buffer : i :  3745
# Replay Buffer : i :  3746
# Replay Buffer : i :  3747
# Replay Buffer : i :  3748
# Replay Buffer : i :  3749
# Replay Buffer : i :  3750
# Replay Buffer : i :  3751
# Replay Buffer : i :  3752
# Replay Buffer : i :  3753
# Replay Buffer : i :  3754
# Replay Buffer : i :  3755
# Replay Buffer : i :  3756
# Replay Buffer : i :  3757
# Replay Buffer : i :  3758
# Replay Buffer : i :  3759
# Replay Buffer : i :  3760
# Replay Buffer : i :  3761
# Replay Buffer : i :  3762
# Replay Buffer : i :  3763
# Replay Buffer : i :  3764
# Replay Buffer : i :  3765
# Replay Buffer : i :  3766
# Replay Buffer : i :  3767
# Replay Buffer : i :  3768
# Replay Buffer : i :  3769
# Replay Buffer : i :  3770
# Replay Buffer : i :  3771
# Replay Buffer : i :  3772
# Replay Buffer : i :  3773
# Replay Buffer : i :  3774
# Replay Buffer : i :  3775
# Replay Buffer : i :  3776
# Replay Buffer : i :  3777
# Replay Buffer : i :  3778
# Replay Buffer : i :  3779
# Replay Buffer : i :  3780
# Replay Buffer : i :  3781
# Replay Buffer : i :  3782
# Replay Buffer : i :  3783
# Replay Buffer : i :  3784
# Replay Buffer : i :  3785
# Replay Buffer : i :  3786
# Replay Buffer : i :  3787
# Replay Buffer : i :  3788
# Replay Buffer : i :  3789
# Replay Buffer : i :  3790
# Replay Buffer : i :  3791
# Replay Buffer : i :  3792
# Replay Buffer : i :  3793
# Replay Buffer : i :  3794
# Replay Buffer : i :  3795
# Replay Buffer : i :  3796
# Replay Buffer : i :  3797
# Replay Buffer : i :  3798
# Replay Buffer : i :  3799
# Replay Buffer : i :  3800
# Replay Buffer : i :  3801
# Replay Buffer : i :  3802
# Replay Buffer : i :  3803
# Replay Buffer : i :  3804
# Replay Buffer : i :  3805
# Replay Buffer : i :  3806
# Replay Buffer : i :  3807
# Replay Buffer : i :  3808
# Replay Buffer : i :  3809
# Replay Buffer : i :  3810
# Replay Buffer : i :  3811
# Replay Buffer : i :  3812
# Replay Buffer : i :  3813
# Replay Buffer : i :  3814
# Replay Buffer : i :  3815
# Replay Buffer : i :  3816
# Replay Buffer : i :  3817
# Replay Buffer : i :  3818
# Replay Buffer : i :  3819
# Replay Buffer : i :  3820
# Replay Buffer : i :  3821
# Replay Buffer : i :  3822
# Replay Buffer : i :  3823
# Replay Buffer : i :  3824
# Replay Buffer : i :  3825
# Replay Buffer : i :  3826
# Replay Buffer : i :  3827
# Replay Buffer : i :  3828
# Replay Buffer : i :  3829
# Replay Buffer : i :  3830
# Replay Buffer : i :  3831
# Replay Buffer : i :  3832
# Replay Buffer : i :  3833
# Replay Buffer : i :  3834
# Replay Buffer : i :  3835
# Replay Buffer : i :  3836
# Replay Buffer : i :  3837
# Replay Buffer : i :  3838
# Replay Buffer : i :  3839
# Replay Buffer : i :  3840
# Replay Buffer : i :  3841
# Replay Buffer : i :  3842
# Replay Buffer : i :  3843
# Replay Buffer : i :  3844
# Replay Buffer : i :  3845
# Replay Buffer : i :  3846
# Replay Buffer : i :  3847
# Replay Buffer : i :  3848
# Replay Buffer : i :  3849
# Replay Buffer : i :  3850
# Replay Buffer : i :  3851
# Replay Buffer : i :  3852
# Replay Buffer : i :  3853
# Replay Buffer : i :  3854
# Replay Buffer : i :  3855
# Replay Buffer : i :  3856
# Replay Buffer : i :  3857
# Replay Buffer : i :  3858
# Replay Buffer : i :  3859
# Replay Buffer : i :  3860
# Replay Buffer : i :  3861
# Replay Buffer : i :  3862
# Replay Buffer : i :  3863
# Replay Buffer : i :  3864
# Replay Buffer : i :  3865
# Replay Buffer : i :  3866
# Replay Buffer : i :  3867
# Replay Buffer : i :  3868
# Replay Buffer : i :  3869
# Replay Buffer : i :  3870
# Replay Buffer : i :  3871
# Replay Buffer : i :  3872
# Replay Buffer : i :  3873
# Replay Buffer : i :  3874
# Replay Buffer : i :  3875
# Replay Buffer : i :  3876
# Replay Buffer : i :  3877
# Replay Buffer : i :  3878
# Replay Buffer : i :  3879
# Replay Buffer : i :  3880
# Replay Buffer : i :  3881
# Replay Buffer : i :  3882
# Replay Buffer : i :  3883
# Replay Buffer : i :  3884
# Replay Buffer : i :  3885
# Replay Buffer : i :  3886
# Replay Buffer : i :  3887
# Replay Buffer : i :  3888
# Replay Buffer : i :  3889
# Replay Buffer : i :  3890
# Replay Buffer : i :  3891
# Replay Buffer : i :  3892
# Replay Buffer : i :  3893
# Replay Buffer : i :  3894
# Replay Buffer : i :  3895
# Replay Buffer : i :  3896
# Replay Buffer : i :  3897
# Replay Buffer : i :  3898
# Replay Buffer : i :  3899
# Replay Buffer : i :  3900
# Replay Buffer : i :  3901
# Replay Buffer : i :  3902
# Replay Buffer : i :  3903
# Replay Buffer : i :  3904
# Replay Buffer : i :  3905
# Replay Buffer : i :  3906
# Replay Buffer : i :  3907
# Replay Buffer : i :  3908
# Replay Buffer : i :  3909
# Replay Buffer : i :  3910
# Replay Buffer : i :  3911
# Replay Buffer : i :  3912
# Replay Buffer : i :  3913
# Replay Buffer : i :  3914
# Replay Buffer : i :  3915
# Replay Buffer : i :  3916
# Replay Buffer : i :  3917
# Replay Buffer : i :  3918
# Replay Buffer : i :  3919
# Replay Buffer : i :  3920
# Replay Buffer : i :  3921
# Replay Buffer : i :  3922
# Replay Buffer : i :  3923
# Replay Buffer : i :  3924
# Replay Buffer : i :  3925
# Replay Buffer : i :  3926
# Replay Buffer : i :  3927
# Replay Buffer : i :  3928
# Replay Buffer : i :  3929
# Replay Buffer : i :  3930
# Replay Buffer : i :  3931
# Replay Buffer : i :  3932
# Replay Buffer : i :  3933
# Replay Buffer : i :  3934
# Replay Buffer : i :  3935
# Replay Buffer : i :  3936
# Replay Buffer : i :  3937
# Replay Buffer : i :  3938
# Replay Buffer : i :  3939
# Replay Buffer : i :  3940
# Replay Buffer : i :  3941
# Replay Buffer : i :  3942
# Replay Buffer : i :  3943
# Replay Buffer : i :  3944
# Replay Buffer : i :  3945
# Replay Buffer : i :  3946
# Replay Buffer : i :  3947
# Replay Buffer : i :  3948
# Replay Buffer : i :  3949
# Replay Buffer : i :  3950
# Replay Buffer : i :  3951
# Replay Buffer : i :  3952
# Replay Buffer : i :  3953
# Replay Buffer : i :  3954
# Replay Buffer : i :  3955
# Replay Buffer : i :  3956
# Replay Buffer : i :  3957
# Replay Buffer : i :  3958
# Replay Buffer : i :  3959
# Replay Buffer : i :  3960
# Replay Buffer : i :  3961
# Replay Buffer : i :  3962
# Replay Buffer : i :  3963
# Replay Buffer : i :  3964
# Replay Buffer : i :  3965
# Replay Buffer : i :  3966
# Replay Buffer : i :  3967
# Replay Buffer : i :  3968
# Replay Buffer : i :  3969
# Replay Buffer : i :  3970
# Replay Buffer : i :  3971
# Replay Buffer : i :  3972
# Replay Buffer : i :  3973
# Replay Buffer : i :  3974
# Replay Buffer : i :  3975
# Replay Buffer : i :  3976
# Replay Buffer : i :  3977
# Replay Buffer : i :  3978
# Replay Buffer : i :  3979
# Replay Buffer : i :  3980
# Replay Buffer : i :  3981
# Replay Buffer : i :  3982
# Replay Buffer : i :  3983
# Replay Buffer : i :  3984
# Replay Buffer : i :  3985
# Replay Buffer : i :  3986
# Replay Buffer : i :  3987
# Replay Buffer : i :  3988
# Replay Buffer : i :  3989
# Replay Buffer : i :  3990
# Replay Buffer : i :  3991
# Replay Buffer : i :  3992
# Replay Buffer : i :  3993
# Replay Buffer : i :  3994
# Replay Buffer : i :  3995
# Replay Buffer : i :  3996
# Replay Buffer : i :  3997
# Replay Buffer : i :  3998
# Replay Buffer : i :  3999
# 400000

# %%
#Setup some parameters for training
timesteps_per_epoch = 2
batch_size = 16
total_steps = 2 * 10**2

# %%
#Optimizer
optimizer = optim.Adam(agent.parameters(),lr=2*1e-5)

# %%
#Setting exploration epsilon
start_epsilon = 0.1
end_epsilon = 0.05
eps_decay_final_step = 1 * 10**1

# %%
#Setup some frequency for logging and updating target network
loss_freq = 20
refresh_target_network_freq = 100
eval_freq = 10000

# %%
#For gradient clipping
max_grad_norm = 5000

mean_rw_history = []
td_loss_history = []

SAVE_INTERVAL = 50000

# %%
from numpy import asarray
from numpy import savetxt

#Defines epsilon schedule
def epsilon_schedule(start_eps, end_eps, step, final_step):
    return start_eps + (end_eps-start_eps)*min(step, final_step)/final_step

#To reset the state of the environment before starting
env.reset()

# %%
### STARTING MAIN LOOP ###
for step in range(total_steps + 1):
    #Updating exploration epsilon
    agent.epsilon = epsilon_schedule(start_epsilon, end_epsilon, step, eps_decay_final_step)

    #Taking timesteps_per_epoch and update experience replay buffer, (use play_and_record)
    play_and_record(state, agent,env,exp_replay,timesteps_per_epoch)

    #Computing TD Loss
    loss = compute_td_loss(agent,target_network,device,batch_size,exp_replay,gamma=0.99)
    #Backward propogation and updating the network parameters
    optimizer.zero_grad()
    loss.backward()
    #Taking optimization step
    optimizer.step()

    if step % loss_freq == 0:
        td_loss_history.append(loss.data.cpu().item())

    # Load agent weights into target_network
    if step % refresh_target_network_freq == 0:
        target_network.load_state_dict(agent.state_dict())

    if step % eval_freq == 0:
        mean_reward = evaluate(make_env(env_name, seed=step), agent, n_games=3, greedy=True, t_max=6000)
        mean_rw_history.append(mean_reward)

        print("mean_reward : ", mean_reward)

        clear_output(True)
        print("buffer size = %i, epsilon = %.5f" %
				(len(exp_replay), agent.epsilon))


    # #Saving
    if step % SAVE_INTERVAL == 0 and step!= 0:
        print('Saving...')
        device = torch.device('cpu')
        torch.save(agent.state_dict(), f'model_{step}.pth')
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        savetxt(f'reward_{step}.csv', np.array(mean_rw_history))
# Out:
# buffer size = 404332, epsilon = 0.10000

# %%
# Final Score
final_score = evaluate(make_env(env_name),agent, n_games=1, greedy=True, t_max=10000)
print('final score:', final_score)
# Out:
# final score: 0.0
